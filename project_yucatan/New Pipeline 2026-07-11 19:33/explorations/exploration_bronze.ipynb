# %%
display(spark.sql(f"""
    SELECT *
    FROM yucatan_project.security_visualization.incidencia_delictiva_estatal_bronze
    LIMIT 10;
"""))

# %%
df = spark.table("yucatan_project.security_visualization.incidencia_delictiva_estatal_bronze")
display(df.dtypes)
