# %%
# %sql
DESCRIBE
    yucatan_project.security_visualization.incidencia_delictiva_municipal_bronze

# %%
# %sql
SELECT
    DISTINCT(entidad)
FROM
    yucatan_project.security_visualization.incidencia_delictiva_municipal_bronze
